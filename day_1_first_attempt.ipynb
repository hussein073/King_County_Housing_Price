# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Stats and distributions
import scipy.stats as stats

# %% [markdown]
# First, we are going to ingest the dataset provided: `kc_house_data.csv`

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0         NaN   0.0     ...          7        1180
# 1      7242     2.0         0.0   0.0     ...          7        2170
# 2     10000     1.0         0.0   0.0     ...          6         770
# 3      5000     1.0         0.0   0.0     ...          7        1050
# 4      8080     1.0         0.0   0.0     ...          8        1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
_ = pd.plotting.scatter_matrix(df, figsize = (16,16))
plt.show()

# %%
df['view'].value_counts()
# Out:
# 0.0    19422
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# Name: view, dtype: int64

# %% [markdown]
# #### Observations
# -`yr_renovated` - Appears to have many `0`'s but also `NaN`s or nulls: should they all be `NaN`? Should be converted to `integer`
# -`waterfront` - Also has `0`'s and `NaN`s, we will make them all `0`s for consistency.
# -`date` - It was imported as an `object`, we will change to `datetime`.
# -`floors` - Appears there are partial floors in the data, which is not intuitive. Will require further research but we will leave as is for now.
# -`condition` - Don't need to worry about. Appears to be a scoring scale from 1-5.
# -`grade` - Makes sense, based on King County grading system. The values aren't entirely clear, we will do more research to understand the values (for example scores of `11`, `12`, and `13`.
# -`sqft_basement` - Was imported as `object`, we will to do a conversion, for example, changing the `?`'s to `0`'s. Also we might consider converted it to `integer` because `sqft_above` is integer, for consistency.
# -`zipcode` - We are considering making them all consistent to 5-digit format.
# -`view` - Contains values 0-4, and the metadata describes it as 'Has been viewed'. Appears to be some sort of bucketing of how often has been viewed.
# -`sqft_living15` and `sqft_lot15` - Our idea is to consider at the end for features, in order to have more clarity of their relationship to the other variables.

# %% [markdown]
# ## First Bad Model!

# %% [markdown]
# For this first attempt we are going to select a basket of variables using our own intuition that has an impact on price:
# - `bedrooms`
# - `bathrooms`
# - `waterfront`
# - `grade`
# - `yr_built`
# - `yr_renovated`
# - `zipcode`

# %%
# Put our selected columns in a list
selected = ['bedrooms','bathrooms','waterfront','grade','yr_built','yr_renovated','zipcode','price']

# %%
# Subset our master dataframe by our selected columns
df_bad = df.loc[:,selected]

# %%
# Check that we got all our desired columsn
df_bad.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'waterfront', 'grade', 'yr_built',
#        'yr_renovated', 'zipcode', 'price'],
#       dtype='object')

# %%
_ = pd.plotting.scatter_matrix(df_bad, figsize = (16,16))
plt.show()

# %% [markdown]
# #### Observations
#
# With respect to price:
# - `bedrooms` - slight positive correlation.
# - `bathrooms` - positive linear correlation.
# - `waterfront` - Inconclusive.
# - `grade` - slight positive correlation.
# - `yr_built` - slight positive correlation.
# - `yr_renovated` - inconclusive, but we haven't cleaned out the 0's yet.
# - `zipcode` - doesn't appear to have a relationship
# - `price` - consider taking the log of it to make it more normally distributed.

# %% [markdown]
# Based on the above we should do a few data cleaning tasks and then take another look at our scatterplots. But maybe let's take a look at histograms of each to see their respective distributions.

# %%
_ = df_bad.hist(figsize=(15,15))

# %% [markdown]
# - `waterfront` - let's look further at the variables of waterfront.
# - `yr_renovated` - clean out the 0's.

# %% [markdown]
# But first, `price` looks very skewed. So for our own understanding let's take the log of it.

# %%
log_price = np.log(df_bad['price'])

# %%
fig, ax = plt.subplots()

ax.hist(log_price)
ax.set_ylabel("LN(price)")
# Out:
# Text(0, 0.5, 'LN(price)')

# %% [markdown]
# Looks more Normal!

# %%
df_bad['waterfront'].value_counts()
# Out:
# 0.0    19075
# 1.0      146
# Name: waterfront, dtype: int64

# %% [markdown]
# `Waterfront` makes sense makes based on this metadata:
# *House which has a view to a waterfront*
#
# Now we will look at `yr_reonvated`.

# %%
df_bad['yr_renovated'].head()
# Out:
# 0       0.0
# 1    1991.0
# 2       NaN
# 3       0.0
# 4       0.0
# Name: yr_renovated, dtype: float64

# %% [markdown]
# We are deciding to convert all the `0`'s to `NaN`s, the reason being that the `0`s make skew any calculations related to the variable, for example `mean`. For plotting we can easily work around by filtering out `NaN`s.

# %%
df_bad.loc[:,['yr_renovated']].replace(0.0,np.nan,inplace=True)

# %%
df_bad['yr_renovated'].replace(0.0,np.nan,inplace=True)

# %%
df_bad['yr_renovated'].head()
# Out:
# 0       NaN
# 1    1991.0
# 2       NaN
# 3       NaN
# 4       NaN
# Name: yr_renovated, dtype: float64

# %%
df_bad['yr_renovated'].value_counts()
# Out:
# 2014.0    73
# 2013.0    31
# 2003.0    31
# 2007.0    30
# 2005.0    29
# 2000.0    29
# 2004.0    22
# 1990.0    22
# 2009.0    21
# 1989.0    20
# 2006.0    20
# 2002.0    17
# 1984.0    16
# 1998.0    16
# 1991.0    16
# 1999.0    15
# 2008.0    15
# 2010.0    15
# 2001.0    15
# 1983.0    15
# 2015.0    14
# 1985.0    14
# 1986.0    14
# 1987.0    14
# 1994.0    14
# 1992.0    13
# 1993.0    12
# 1997.0    12
# 1995.0    12
# 1996.0    11
#           ..
# 1975.0     5
# 1964.0     5
# 1969.0     4
# 1963.0     4
# 1973.0     4
# 1981.0     4
# 1965.0     4
# 1978.0     3
# 1960.0     3
# 1958.0     3
# 1956.0     3
# 1955.0     3
# 1945.0     3
# 1972.0     3
# 1967.0     2
# 1957.0     2
# 1940.0     2
# 1974.0     2
# 1962.0     2
# 1953.0     1
# 1950.0     1
# 1934.0     1
# 1944.0     1
# 1976.0     1
# 1948.0     1
# 1946.0     1
# 1959.0     1
# 1971.0     1
# 1951.0     1
# 1954.0     1
# Name: yr_renovated, Length: 69, dtype: int64

# %%
df_bad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 8 columns):
# bedrooms        21597 non-null int64
# bathrooms       21597 non-null float64
# waterfront      19221 non-null float64
# grade           21597 non-null int64
# yr_built        21597 non-null int64
# yr_renovated    744 non-null float64
# zipcode         21597 non-null int64
# price           21597 non-null float64
# dtypes: float64(4), int64(4)
# memory usage: 1.3 MB

# %% [markdown]
# ## Let's start modeling!

# %%
import statsmodels.api as sm

# %%
df_bad[selected].head()
# Out:
#    bedrooms  bathrooms  waterfront  grade  yr_built  yr_renovated  zipcode  \
# 0         3       1.00         NaN      7      1955           NaN    98178
# 1         3       2.25         0.0      7      1951        1991.0    98125
# 2         2       1.00         0.0      6      1933           NaN    98028
# 3         4       3.00         0.0      7      1965           NaN    98136
# 4         3       2.00         0.0      8      1987           NaN    98074
#
#       price
# 0  221900.0
# 1  538000.0
# 2  180000.0
# 3  604000.0
# 4  510000.0

# %%
df_bad_predictors = df_bad.drop(['price'], axis=1)
df_bad_predictors.head()
# Out:
#    bedrooms  bathrooms  waterfront  grade  yr_built  yr_renovated  zipcode
# 0         3       1.00         NaN      7      1955           NaN    98178
# 1         3       2.25         0.0      7      1951        1991.0    98125
# 2         2       1.00         0.0      6      1933           NaN    98028
# 3         4       3.00         0.0      7      1965           NaN    98136
# 4         3       2.00         0.0      8      1987           NaN    98074

# %%
df_bad_tgt = df_bad['price']
df_bad_tgt.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
# Set up predictors
predictors = sm.add_constant(df_bad_predictors)

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 8 columns):
# const           21597 non-null float64
# bedrooms        21597 non-null int64
# bathrooms       21597 non-null float64
# waterfront      19221 non-null float64
# grade           21597 non-null int64
# yr_built        21597 non-null int64
# yr_renovated    744 non-null float64
# zipcode         21597 non-null int64
# dtypes: float64(4), int64(4)
# memory usage: 1.3 MB

# %%
# Model SM LR model
model_sm = sm.OLS(df_bad_tgt, predictors).fit()

# View Results
model_sm.summary()
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-67-3d94b18ed604> in <module>()
#       3
#       4 # Model SM LR model
# ----> 5 model_sm = sm.OLS(df_bad_tgt, predictors).fit()
#       6
#       7 # View Results
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     815                  **kwargs):
#     816         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 817                                   hasconst=hasconst, **kwargs)
#     818         if "weights" in self._init_keys:
#     819             self._init_keys.remove("weights")
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
# ...

# %% [markdown]
# We can't have `NaN` values for the predictor variables! So for now, let's just remove the column(s) that have them and clean them further after this initial model.

# %%
df_bad_predictors = df_bad.drop(['price','yr_renovated','waterfront'], axis=1)
df_bad_predictors.head()
# Out:
#    bedrooms  bathrooms  grade  yr_built  zipcode
# 0         3       1.00      7      1955    98178
# 1         3       2.25      7      1951    98125
# 2         2       1.00      6      1933    98028
# 3         4       3.00      7      1965    98136
# 4         3       2.00      8      1987    98074

# %%
df_bad_predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 5 columns):
# bedrooms     21597 non-null int64
# bathrooms    21597 non-null float64
# grade        21597 non-null int64
# yr_built     21597 non-null int64
# zipcode      21597 non-null int64
# dtypes: float64(1), int64(4)
# memory usage: 843.7 KB

# %% [markdown]
# We've `drop`ped the columns with `NaN`s for now for our initial model (`waterfront` and `yr_renovated`).

# %%
# Set up predictors
predictors = sm.add_constant(df_bad_predictors)

# Model SM LR model
model_sm = sm.OLS(df_bad_tgt, predictors).fit()

# View Results
model_sm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.564
# Method:                 Least Squares   F-statistic:                     5578.
# Date:                Mon, 15 Apr 2019   Prob (F-statistic):               0.00
# Time:                        11:23:17   Log-Likelihood:            -2.9844e+05
# No. Observations:               21597   AIC:                         5.969e+05
# Df Residuals:                   21591   BIC:                         5.969e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.453e+07   3.29e+06      4.413      0.000    8.07e+06     2.1e+07
# ...

# %% [markdown]
# #### Initial observations
# - $R^2$ (and $R^2_{adj}$) are not too bad at .564. But definitely could be improved on!
# - All the variables are statistically significant ( p-values <0.05) with the exception of `zipcode`, which as a p-value of 0.054. Might look into dropping it.

# %%
fig2 = plt.figure(figsize=(12,12))
fig = sm.graphics.plot_regress_exog(model_sm,"yr_built",fig=fig2)
plt.show()

# %%
residuals = model_sm.resid
fig = sm.graphics.qqplot(residuals, dist=stats.norm, line='45', fit=True)
fig.show()
# Out:
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# #### Observations
# qqplot shows that residuals are definitely not normal, so there are remaining issues with one or more of the following:
# - Outliers within `price` or other variables.
# - Normality of `price` or other variables.
